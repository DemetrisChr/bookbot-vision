# %% [markdown]
# ## Text recognition
# Load an image of a book label isolated by Dimitris and use tesseract to read the text on it.
# Needs tesseract installed to work.

# %%
import pytesseract
#Next line only necessary for Windows
#pytesseract.pytesseract.tesseract_cmd='C:\Program Files\Tesseract-OCR\\tesseract'

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

import sys
sys.path.insert(1, '../scripts/')
import identification as iden

# %%
img = cv2.imread('pictures/label1.png')
plt.imshow(img)

# %%
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'
text=pytesseract.image_to_string(img)
print(text)
# Out:
# GN
# 496
# Ign.

# %%
text
# Out:
# 'GN\n496\nIgn.'

# %%
for i in range(1,15):

# %%
for i in range(1,15):
    img = cv2.imread('../scripts/label'+str(i)+'.png', 0)
    img = cv2.GaussianBlur(img,(5,5),0)
    scale_percent = 200 # percent of original size
    width = int(img.shape[1] * scale_percent / 100)
    height = int(img.shape[0] * scale_percent / 100)
    dim = (width, height)
    # resize image
    img = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)
    img = cv2.copyMakeBorder(resized, top=100, bottom=100, left=100, right=100, borderType=cv2.BORDER_CONSTANT, value=255)
    kernel = np.ones((5,5),np.uint8)
    # resized = cv2.dilate(resized,kernel,iterations = 1)
    img = cv2.bilateralFilter(img,9,75,75)
    plt.figure()
    plt.imshow(resized, cmap='gray')
    plt.show()
    text=pytesseract.image_to_string(resized, config='config')
    print(text)

# %%
for i in range(1,16):
    img = cv2.imread('../scripts/label'+str(i)+'.png', 0)
    
    scale_percent = 200 # percent of original size
    width = int(img.shape[1] * scale_percent / 100)
    height = int(img.shape[0] * scale_percent / 100)
    dim = (width, height)
    img = cv2.resize(img, None, fx=2.0, fy=2.0, interpolation = cv2.INTER_AREA)
    
    # img = cv2.GaussianBlur(img,(9,9),0)
    img = iden.rowLuminosityBinarisation(img, num_intervals=20, threshold_coef=0.75)
    img = cv2.copyMakeBorder(img, top=50, bottom=50, left=50, right=50, borderType=cv2.BORDER_CONSTANT, value=255)
    plt.figure()
    plt.imshow(img, cmap='gray')
    plt.show()
    text=pytesseract.image_to_string(img, config='config')
    print(text)
# Out:
# 441
# | Ash.
# TT
#
# Vau.
# 394
# -H857
# Car.
# 334
# 54
# Swa.
# iss] SLAVERY, CAPITALISM, AND POLITICS IN THE ANTEBELLUM REPUBLIC
#
# ASHWORTH
# ' 8
# ) GILBERT HERDT
#
#
#
# ——o
#
# THE SAMBIA Ritual and Gender in New Guinea
#
# HOLT + RIN
#
# i
# CQ
#
# 7)
# NI
# N xt
#
# Her

# %%
img = cv2.imread('pictures/books1.jpg', 0)
img = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_MEAN_C,\
            cv2.THRESH_BINARY,11,2)
plt.figure(figsize=(18,12))
plt.imshow(img, cmap='gray')
plt.show()
